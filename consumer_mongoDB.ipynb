# %%
from kafka import KafkaConsumer
import json
from pymongo import MongoClient

# %%
consumer = KafkaConsumer('test5',bootstrap_servers='sandbox-hdf.hortonworks.com:6667',api_version=(0, 10, 1))

# %%
for message in consumer:
    print(message)
# Out:
# ConsumerRecord(topic='test5', partition=0, offset=14, timestamp=1582011153829, timestamp_type=0, key=None, value=b'four', headers=[], checksum=2090586206, serialized_key_size=-1, serialized_value_size=4, serialized_header_size=-1)
# ConsumerRecord(topic='test5', partition=0, offset=15, timestamp=1582976581189, timestamp_type=0, key=None, value=b'Hello, World!', headers=[], checksum=2043297149, serialized_key_size=-1, serialized_value_size=13, serialized_header_size=-1)

# %%
# Setup mongo connection
client = MongoClient(port=27017)
db = client.spa

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'spa')

# %%
#check mongo db
import random
names = ['Kitchen','Animal','State', 'Tastey', 'Big','City','Fish', 'Pizza','Goat', 'Salty','Sandwich','Lazy', 'Fun']
company_type = ['LLC','Inc','Company','Corporation']
company_cuisine = ['Pizza', 'Bar Food', 'Fast Food', 'Italian', 'Mexican', 'American', 'Sushi Bar', 'Vegetarian']
for x in range(1, 501):
    business = {
        'name' : names[random.randint(0, (len(names)-1))] + ' ' + names[random.randint(0, (len(names)-1))]  + ' ' + company_type[random.randint(0, (len(company_type)-1))],
        'rating' : random.randint(1, 5),
        'cuisine' : company_cuisine[random.randint(0, (len(company_cuisine)-1))] 
    }
    #Step 3: Insert business object directly into MongoDB via isnert_one
    result=db.kafka_data.insert_one(business)
    #Step 4: Print to the console the ObjectID of the new document
    print('Created {0} of 500 as {1}'.format(x,result.inserted_id))
#Step 5: Tell us that you are done
print('finished creating 500 business reviews')
# Out:
# Created 1 of 500 as 5e58efac0a63f61eac2b025c
# Created 2 of 500 as 5e58efad0a63f61eac2b025d
# Created 3 of 500 as 5e58efad0a63f61eac2b025e
# Created 4 of 500 as 5e58efad0a63f61eac2b025f
# Created 5 of 500 as 5e58efad0a63f61eac2b0260
# Created 6 of 500 as 5e58efad0a63f61eac2b0261
# Created 7 of 500 as 5e58efad0a63f61eac2b0262
# Created 8 of 500 as 5e58efad0a63f61eac2b0263
# Created 9 of 500 as 5e58efad0a63f61eac2b0264
# Created 10 of 500 as 5e58efad0a63f61eac2b0265
# Created 11 of 500 as 5e58efad0a63f61eac2b0266
# Created 12 of 500 as 5e58efad0a63f61eac2b0267
# Created 13 of 500 as 5e58efad0a63f61eac2b0268
# Created 14 of 500 as 5e58efad0a63f61eac2b0269
# Created 15 of 500 as 5e58efad0a63f61eac2b026a
# Created 16 of 500 as 5e58efad0a63f61eac2b026b
# Created 17 of 500 as 5e58efad0a63f61eac2b026c
# Created 18 of 500 as 5e58efad0a63f61eac2b026d
# Created 19 of 500 as 5e58efad0a63f61eac2b026e
# Created 20 of 500 as 5e58efad0a63f61eac2b026f
# Created 21 of 500 as 5e58efad0a63f61eac2b0270
# ...

# %%
for msg in consumer:
    msg_json = json.loads(msg.value)
    print(db.kafka_data.insert_one(msg_json).inserted_id)
# Out:
# 5e58fe009c1473dc63da5397
# 5e58fe059c1473dc63da5398
# 5e58fe1b9c1473dc63da5399
# 5e5901d69c1473dc63da539a
# 5e5901de9c1473dc63da539b
